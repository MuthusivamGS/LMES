# %% [markdown]
# ## C10 - Deep Dive into Python Libraries and its usage for Data Science

# %% [markdown]
# ### Online Class Interractions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Kindly note the following points for smooth Online Class Interractions:***
# 1. This Online Class content is ***recorded and shared among this course Learners*** for future reference of the content
# 2. Please click the **Raise Hand** option when you need to speak during live class
# 3. Share your **computer screen**, for discussing technical content questions, only when asked by the Tutor
# 4. ***For quick interractions during live class***     - please type in the **Chat section** with simple answers, thoughts, or suggestions
# 5. ***For technical content questions in the course*** - you can ask the Tutor
# 6. ***For any other questions about the course*** - you can ask the course Coordinator

# %% [markdown]
# ### Feedback form

# %% [markdown]
# ### Assignment-1 Reminder (Deadline: 12/01/2025)

# %% [markdown]
# ### [5m] Previous class recap

# %% [markdown]
# ### [45m] Pandas

# %% [markdown]
# - **Pandas** is a Python library used for Data manipulation
# - Pandas can be installed by,
#     - Clicking the **.venv** folder
#         - Right-click **Scripts** folder
#         - Click the option "**Open in Integrated Terminal**"
#         - Run the command "**python -m pip install pandas**" in the terminal
# - Reference for pip: https://en.wikipedia.org/wiki/Pip_(package_manager)
#     - pip (also known by Python 3's alias pip3) is a package-management system written in Python and is used to install and manage software packages.
# - Pandas commands user guide: https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %%
import pandas as pd

# %% [markdown]
# Types of file:
# - CSV (Comma Separated Files)
# - Excel (.xlsx)
# - JSON
# - etc.

# %% [markdown]
# #### Reading a file

# %%
# Reading text file with Pandas
pd.read_table('c10-data.txt')
# Out:
#   Vanakkam - This is my First line
# 0                      Second line
# 1                      Third line

# %%
# DataFrame
# 2 dimensional object - like a matrix
# columns and rows

# Reading csv file with Pandas
df = pd.read_csv("Sleep_Efficiency.csv")

# The head() command takes only the first 5 lines by default
#df = df.head(n=3)
df = df.head()  # Shows first 5 rows
#df = df.tail()  # Shows last 5 rows
#print(df)
df
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
#print(df)

# %%
# "df" is a variable name
# That Python variable currently holds a DataFrame
# That DataFrame is a Pandas object
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Simple DataFrame operations

# %%
# Getting the column names of a DataFrame
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Bedtime', 'Wakeup time', 'Sleep duration',
#        'Sleep efficiency', 'REM sleep percentage', 'Deep sleep percentage',
#        'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#        'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#       dtype='object')

# %%
# Getting the shape (of rows and columns) of a DataFrame
df.shape
# Out:
# (5, 15)

# %%
# Getting column-wise information about the DataFrame content
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      5 non-null      int64
#  1   Age                     5 non-null      int64
#  2   Gender                  5 non-null      object
#  3   Bedtime                 5 non-null      object
#  4   Wakeup time             5 non-null      object
#  5   Sleep duration          5 non-null      float64
#  6   Sleep efficiency        5 non-null      float64
#  7   REM sleep percentage    5 non-null      int64
#  8   Deep sleep percentage   5 non-null      int64
#  9   Light sleep percentage  5 non-null      int64
#  10  Awakenings              5 non-null      float64
#  11  Caffeine consumption    5 non-null      float64
#  12  Alcohol consumption     5 non-null      float64
#  13  Smoking status          5 non-null      object
# ...

# %%
# Creating a Pandas DataFrame manually by passing the data as list in DataFrame() function
pd.DataFrame(["row1","row2"],[123, 456])
# Out:
#         0
# 123  row1
# 456  row2

# %%
# Creating a Pandas DataFrame manually by passing the data as dictionary in DataFrame() function
pd.DataFrame({"column1":[1,2,3],
              "column2":['a','b','c'],
              "column3":['x','y','z']})
# Out:
#    column1 column2 column3
# 0        1       a       x
# 1        2       b       y
# 2        3       c       z

# %% [markdown]
# #### Fetching Column data

# %%
df
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
# To fetch data from a column - By giving the "position"
df.iloc[:,2]
# Out:
# 0    Female
# 1      Male
# 2    Female
# 3    Female
# 4      Male
# Name: Gender, dtype: object

# %%
# To fetch data from a column - By giving the "position"
df.iloc[:,[2]]
# Out:
#    Gender
# 0  Female
# 1    Male
# 2  Female
# 3  Female
# 4    Male

# %%
# To fetch data from multiple columns - By giving the "position"
df.iloc[:,[1,2,3,4]]
# Out:
#    Age  Gender              Bedtime          Wakeup time
# 0   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00

# %%
# To fetch data from multiple columns - By giving the "position" range
# df.iloc[:,[1:5]]  # SyntaxError: invalid syntax

df.iloc[:,1:5]
# Out:
#    Age  Gender              Bedtime          Wakeup time
# 0   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00

# %%
# To fetch data from multiple columns - By giving specific column name

#need_to_fetch = ["Age", "Gender", "Bedtime", "Wakeup time"]
#df[need_to_fetch]

df[["Age", "Gender", "Bedtime", "Wakeup time"]]
# Out:
#    Age  Gender              Bedtime          Wakeup time
# 0   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00

# %%
# An example scenario of same names
#df.columns = ["names","names","names","names"]
#df["names"]

#df[{"Gender", "Gender", "Gender"}]  # TypeError: Passing a set as an indexer is not supported. Use a list instead.

df[["Gender", "Gender", "Gender"]]
# Out:
#    Gender  Gender  Gender
# 0  Female  Female  Female
# 1    Male    Male    Male
# 2  Female  Female  Female
# 3  Female  Female  Female
# 4    Male    Male    Male

# %%
# Q/A

df.iloc[:,:5]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00

# %%
# Q/A

# df.iloc[:,["Age","Wakeup time"]]  # IndexError: .iloc requires numeric indexers, got ['Age' 'Wakeup time']

# %% [markdown]
# #### Removing a Row or Column in a DataFrame

# %%
# To remove a row
# df.drop([0], axis=0)

df.drop([0])
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
# To remove a column
df.drop(["Gender"], axis=1)
# Out:
#    ID  Age              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 0                      12         0.0                   0.0
# ...

# %% [markdown]
# #### Fetching Row data

# %%
# Using iloc function, To fetch data from multiple rows - By giving the "position"
#df.iloc[[1,4]]
df.iloc[[1,4],:]
# Out:
#    ID  Age Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 4   5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 1                  3.0            Yes                 3.0
# 4                  3.0             No                 3.0

# %%
df.iloc[1:4,:]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 1                  3.0            Yes                 3.0
# ...

# %% [markdown]
# #### Difference between loc and iloc

# %%
df
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
df = df.drop([0])

# %%
df
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
# Using iloc function, To fetch data from multiple rows - By giving the "position" range
df.iloc[1:4]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 2                  0.0             No                 3.0
# ...

# %%
# Using loc function, To fetch data from multiple rows - By giving the "position" range
df.loc[1:4]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
# Getting a row using single row number with iloc
#df.iloc[0]

# Getting a row using single row number with iloc
#df.iloc[[0]]

# Getting rows using multiple row numbers with iloc
#df.iloc[[0,4]]

# Getting rows using a range of row numbers with iloc
#df.iloc[0:4]

# %%
df.iloc[0]
# Out:
# ID                                          2
# Age                                        69
# Gender                                   Male
# Bedtime                   2021-12-05 02:00:00
# Wakeup time               2021-12-05 09:00:00
# Sleep duration                            7.0
# Sleep efficiency                         0.66
# REM sleep percentage                       19
# Deep sleep percentage                      28
# Light sleep percentage                     53
# Awakenings                                3.0
# Caffeine consumption                      0.0
# Alcohol consumption                       3.0
# Smoking status                            Yes
# Exercise frequency                        3.0
# Name: 1, dtype: object

# %%
df.iloc[[0]]
# Out:
#    ID  Age Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 1                  3.0            Yes                 3.0

# %%
df.iloc[[0,3]]
# Out:
#    ID  Age Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69   Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 4   5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 1                  3.0            Yes                 3.0
# 4                  3.0             No                 3.0

# %%
df.iloc[0:4]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
# Getting a row using single row number with loc
#df.loc[0]

# Getting a row using single row number with loc
#df.loc[[0]]

# Getting rows using multiple row numbers with loc
#df.loc[[0,4]]

# Getting rows using a range of row numbers with loc
#df.loc[0:4]

# %%
df
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
df.loc[0]  # KeyError: 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df.loc[0]
#
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df.loc[[0]]  # KeyError: "None of [Index([0], dtype='int64')] are in the [index]"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.loc[[0]]
#
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %%
df.loc[[0,4]]  # KeyError: '[0] not in index'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df.loc[[0,4]]  # KeyError: '[0] not in index'
#
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\DS_course\Batch-302\.venv\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %%
df.loc[[4]]
# Out:
#    ID  Age Gender              Bedtime          Wakeup time  Sleep duration  \
# 4   5   57   Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 4                  3.0             No                 3.0

# %%
#df.loc[0:10]
df.loc[0:4]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 1                      53         3.0                   0.0
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# ...

# %%
df.iloc[1:4]
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 2                      10         1.0                   0.0
# 3                      52         3.0                  50.0
# 4                      18         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 2                  0.0             No                 3.0
# ...

# %% [markdown]
# #### Resetting of DataFrame index

# %%
# Reindexing the DataFrame index to make continuous row number from start to end
# This is done to have proper row numbering, because we previously deleted some rows during data processing
df.reset_index()
# Out:
#    index  ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 1      2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 2      3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 3      4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
#
#    Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0             7.0              0.66                    19
# 1             8.0              0.89                    20
# 2             6.0              0.51                    23
# 3             8.0              0.76                    27
#
#    Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                     28                      53         3.0
# 1                     70                      10         1.0
# 2                     25                      52         3.0
# 3                     55                      18         3.0
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 1   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 2   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 3   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.66                    19                     28
# 1              0.89                    20                     70
# 2              0.51                    23                     25
# 3              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 0                      53         3.0                   0.0
# 1                      10         1.0                   0.0
# 2                      52         3.0                  50.0
# ...

# %% [markdown]
# ### [15m] Numpy
# - https://numpy.org/doc/stable/reference/

# %%
# Numpy is a Python library used for Numerical analysis
# Numpy is the core library on top of which Pandas is built
# Numpy can be installed by running "python -m pip install numpy" in the terminal
import numpy as np

# %%
from numpy import random

# Getting a random number less than the given number
random.randint(100)
# Out:
# 5

# %%
# Reference: https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html

np.random.randint(60, 100, 70)
# Out:
# array([98, 88, 84, 88, 78, 63, 91, 96, 82, 72, 92, 93, 98, 96, 65, 97, 64,
#        69, 64, 92, 85, 67, 60, 65, 61, 84, 64, 78, 61, 81, 77, 91, 66, 90,
#        71, 77, 93, 86, 64, 70, 99, 91, 72, 85, 78, 70, 65, 77, 97, 74, 99,
#        83, 63, 88, 88, 92, 82, 95, 89, 90, 69, 61, 83, 85, 92, 84, 99, 75,
#        92, 77], dtype=int32)

# %%
# Creating a numpy array
test_array = np.array([1,2,3,4])

# print(test_array)
# print(type(test_array))

print(test_array)
type(test_array)
# Out:
# [1 2 3 4]
# numpy.ndarray

# %%
# Finding the square root of a number
np.sqrt(4)
# Out:
# np.float64(2.0)

# %% [markdown]
# ### [30m] Other libraries in Python for Data Science
# - **Visualization**
#     - Matplotlib - https://matplotlib.org/stable/users/index.html
#     - Seaborn - https://seaborn.pydata.org/tutorial.html
#     - Plotly - https://plotly.com/python/plotly-fundamentals/
# - **Statistics and Machine Learning**
#     - Statsmodels - https://www.statsmodels.org/stable/user-guide.html
#     - NLTK - (https://www.nltk.org/book/ch01.html)
#     - Scikit-learn - https://scikit-learn.org/stable/user_guide.html
# - etc.

# %% [markdown]
# ### Feedback form

# %% [markdown]
# ### Assignment-1 Reminder (Deadline: 12/01/2025)

# %% [markdown]
# ### [45m] Start Assignment-1 and doubt clearing
